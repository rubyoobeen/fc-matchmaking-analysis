# %%
import json
import pandas as pd

# Load your saved data
with open("../data/matches_raw.json", "r", encoding="utf-8") as f:
    matches = json.load(f)

# See how many matches and what the first one looks like
print(f"Total matches: {len(matches)}")
print(f"\nFirst match structure:")
print(json.dumps(matches[0], indent=2, ensure_ascii=False))
# Out:
# Total matches: 100
#
# First match structure:
# {
#   "matchId": "69290fab06827859169449be",
#   "matchDate": "2025-11-28T02:59:19",
#   "matchType": 30,
#   "matchInfo": [
#     {
#       "ouid": "649d8eb4607fae9f26e541c5867403de",
#       "nickname": "vsk1234",
#       "matchDetail": {
#         "seasonId": null,
#         "matchResult": "패",
#         "matchEndType": 2,
#         "systemPause": 0,
#         "foul": 0,
#         "injury": 0,
#         "redCards": 0,
#         "yellowCards": 0,
#         "dribble": 3,
#         "cornerKick": 0,
#         "possession": 46,
#         "offsideCount": 0,
#         "averageRating": 4.06667,
#         "controller": "keyboard"
#       },
#       "shoot": {
#         "shootTotal": 0,
#         "effectiveShootTotal": 0,
#         "shootOutScore": 0,
#         "goalTotal": 0,
#         "goalTotalDisplay": 0,
#         "ownGoal": 0,
#         "shootHeading": 0,
#         "goalHeading": 0,
#         "shootFreekick": 0,
# ...
